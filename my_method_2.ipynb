# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import os

os.environ["CUDA_VISIBLE_DEVICES"] = "0"
config = tf.ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = 0.5
config.gpu_options.allow_growth = True

# %%
def xavier_init(size):
    in_dim = size[0]
    xavier_stddev = 1. / tf.sqrt(in_dim / 2.)
    return tf.random_normal(shape=size, stddev=xavier_stddev)


X = tf.placeholder(tf.float32, shape=[None, 784])

D_W1 = tf.Variable(xavier_init([784, 128]))
D_b1 = tf.Variable(tf.zeros(shape=[128]))

D_W2 = tf.Variable(xavier_init([128, 1]))
D_b2 = tf.Variable(tf.zeros(shape=[1]))

theta_D = [D_W1, D_W2, D_b1, D_b2]

Z = tf.placeholder(tf.float32, shape=[None, 784])

G_W1 = tf.Variable(xavier_init([784, 128]))
G_b1 = tf.Variable(tf.zeros(shape=[128]))

G_W2 = tf.Variable(xavier_init([128, 784]))
G_b2 = tf.Variable(tf.zeros(shape=[784]))

theta_G = [G_W1, G_W2, G_b1, G_b2]


def sample_Z(m, n):
    return np.random.uniform(-1., 1., size=[m, n])


def generator(z):
    G_h1 = tf.nn.relu(tf.matmul(z, G_W1) + G_b1)
    G_log_prob = tf.matmul(G_h1, G_W2) + G_b2
    G_prob = tf.nn.sigmoid(G_log_prob)

    return G_prob


def discriminator(x):
    D_h1 = tf.nn.relu(tf.matmul(x, D_W1) + D_b1)
    D_logit = tf.matmul(D_h1, D_W2) + D_b2
    D_prob = tf.nn.sigmoid(D_logit)

    return D_prob, D_logit


def plot_sample(samples):
    fig = plt.figure(figsize=(4, 4))
    gs = gridspec.GridSpec(4, 4)
    gs.update(wspace=0.05, hspace=0.05)

    for i, sample in enumerate(samples):
        ax = plt.subplot(gs[i])
        plt.axis('off')
        ax.set_xticklabels([])
        ax.set_yticklabels([])
        ax.set_aspect('equal')
        plt.imshow(sample.reshape(28, 28), cmap='Greys_r')

    return fig


def plot_loss(G_iteration_list, G_loss_list, D_iteration_list, D_loss_list):
    fig = plt.figure()
    plt.plot(G_iteration_list, G_loss_list, 'r')
    plt.plot(D_iteration_list, D_loss_list, 'y')
    plt.xlabel('iteration')
    plt.ylabel('loss')
    plt.legend(['G_loss', 'D_loss'])
    plt.title("G_loss VS D_loss")
    return fig


G_sample = generator(Z)
D_real, D_logit_real = discriminator(X)
D_fake, D_logit_fake = discriminator(G_sample)

# D_loss = -tf.reduce_mean(tf.log(D_real) + tf.log(1. - D_fake))
# G_loss = -tf.reduce_mean(tf.log(D_fake))

# Alternative losses:
# -------------------
D_loss_real = tf.reduce_mean(
    tf.nn.sigmoid_cross_entropy_with_logits(
        logits=D_logit_real, labels=tf.ones_like(D_logit_real)))
D_loss_fake = tf.reduce_mean(
    tf.nn.sigmoid_cross_entropy_with_logits(
        logits=D_logit_fake, labels=tf.zeros_like(D_logit_fake)))
D_loss = D_loss_real + D_loss_fake
G_loss = tf.reduce_mean(
    tf.nn.sigmoid_cross_entropy_with_logits(
        logits=D_logit_fake, labels=tf.ones_like(D_logit_fake)))

D_solver = tf.train.AdamOptimizer().minimize(D_loss, var_list=theta_D)
G_solver = tf.train.AdamOptimizer().minimize(G_loss, var_list=theta_G)

mb_size = 128
Z_dim = 784

mnist = tf.contrib.learn.datasets.mnist.read_data_sets(
    train_dir='mnist/data', one_hot=True)

if not os.path.exists('my_method2/'):
    os.makedirs('my_method2/')

i = 0
G_iteration_list = []
G_loss_list = []
D_iteration_list = []
D_loss_list = []
with tf.Session(config=config) as sess:
    sess.run(tf.global_variables_initializer())
    for it in range(100000):
        if it % 1000 == 0:
            samples = sess.run(G_sample, feed_dict={Z: sample_Z(16, Z_dim)})

            fig = plot_sample(samples)
            plt.savefig(
                'my_method2/{}.png'.format(str(i).zfill(3)),
                bbox_inches='tight')
            i += 1
            plt.show()
            plt.close(fig)

        X_mb, _ = mnist.train.next_batch(mb_size)

        _, D_loss_curr = sess.run(
            [D_solver, D_loss],
            feed_dict={
                X: X_mb,
                Z: sample_Z(mb_size, Z_dim)
            })
        _, G_loss_curr = sess.run(
            [G_solver, G_loss], feed_dict={
                Z: sample_Z(mb_size, Z_dim)
            })
        G_iteration_list.append(it)
        D_iteration_list.append(it)
        G_loss_list.append(G_loss_curr)
        D_loss_list.append(D_loss_curr)

        if it % 1000 == 0:
            fig = plot_loss(G_iteration_list, G_loss_list, D_iteration_list,
                            D_loss_list)
            plt.show()
            plt.close(fig)
            print('Iter: {}'.format(it))
            print('D loss: {:.4}'.format(D_loss_curr))
            print('G_loss: {:.4}'.format(G_loss_curr))
            print()
# Out:
# Extracting mnist/data/train-images-idx3-ubyte.gz
# Extracting mnist/data/train-labels-idx1-ubyte.gz
# Extracting mnist/data/t10k-images-idx3-ubyte.gz
# Extracting mnist/data/t10k-labels-idx1-ubyte.gz
# Iter: 0
# D loss: 1.591
# G_loss: 2.387
# Iter: 1000
# D loss: 0.007279
# G_loss: 11.21
# Iter: 2000
# D loss: 0.0151
# G_loss: 8.326
# Iter: 3000
# D loss: 0.01733
# G_loss: 6.687
# Iter: 4000
# D loss: 0.09224
# G_loss: 5.642
# Iter: 5000
# D loss: 0.1455
# G_loss: 6.097
# Iter: 6000
# D loss: 0.2735
# G_loss: 4.344
# Iter: 7000
# D loss: 0.4113
# G_loss: 4.232
# Iter: 8000
# D loss: 0.4477
# G_loss: 3.905
# Iter: 9000
# D loss: 0.6859
# G_loss: 3.137
# Iter: 10000
# D loss: 0.4547
# G_loss: 2.811
# Iter: 11000
# D loss: 0.4337
# G_loss: 2.754
# Iter: 12000
# D loss: 0.6028
# G_loss: 2.685
# Iter: 13000
# D loss: 0.5319
# G_loss: 2.778
# Iter: 14000
# D loss: 0.5112
# G_loss: 2.355
# Iter: 15000
# D loss: 0.7371
# G_loss: 2.798
# Iter: 16000
# D loss: 0.4242
# G_loss: 2.758
# Iter: 17000
# D loss: 0.673
# G_loss: 2.738
# Iter: 18000
# D loss: 0.575
# G_loss: 2.592
# Iter: 19000
# D loss: 0.5315
# G_loss: 2.884
# Iter: 20000
# D loss: 0.6094
# G_loss: 2.646
# Iter: 21000
# D loss: 0.6747
# G_loss: 2.266
# Iter: 22000
# D loss: 0.5429
# G_loss: 2.75
# Iter: 23000
# D loss: 0.6341
# G_loss: 2.729
# Iter: 24000
# D loss: 0.6355
# G_loss: 2.472
# Iter: 25000
# D loss: 0.572
# G_loss: 2.35
# Iter: 26000
# D loss: 0.5891
# G_loss: 2.611
# Iter: 27000
# D loss: 0.4642
# G_loss: 2.576
# Iter: 28000
# D loss: 0.5153
# G_loss: 2.519
# Iter: 29000
# D loss: 0.6717
# G_loss: 2.584
# Iter: 30000
# D loss: 0.5198
# G_loss: 2.712
# Iter: 31000
# D loss: 0.5754
# G_loss: 3.113
# Iter: 32000
# D loss: 0.5241
# G_loss: 2.595
# Iter: 33000
# D loss: 0.6564
# G_loss: 2.489
# Iter: 34000
# D loss: 0.6146
# G_loss: 2.741
# Iter: 35000
# D loss: 0.6125
# G_loss: 2.72
# Iter: 36000
# D loss: 0.5157
# G_loss: 2.595
# Iter: 37000
# D loss: 0.4546
# G_loss: 3.299
# Iter: 38000
# D loss: 0.6168
# G_loss: 3.676
# Iter: 39000
# D loss: 0.4331
# G_loss: 3.272
# Iter: 40000
# D loss: 0.4856
# G_loss: 2.736
# Iter: 41000
# D loss: 0.3952
# G_loss: 2.959
# Iter: 42000
# D loss: 0.4561
# G_loss: 2.989
# Iter: 43000
# D loss: 0.4602
# G_loss: 2.859
# Iter: 44000
# D loss: 0.4944
# G_loss: 2.899
# Iter: 45000
# D loss: 0.396
# G_loss: 3.453
# Iter: 46000
# D loss: 0.5091
# G_loss: 2.795
# Iter: 47000
# D loss: 0.502
# G_loss: 3.011
# Iter: 48000
# D loss: 0.4673
# G_loss: 2.99
# Iter: 49000
# D loss: 0.4798
# G_loss: 3.018
# Iter: 50000
# D loss: 0.5083
# G_loss: 3.122
# Iter: 51000
# D loss: 0.4161
# G_loss: 3.545
# Iter: 52000
# D loss: 0.5098
# G_loss: 3.07
# Iter: 53000
# D loss: 0.4038
# G_loss: 3.106
# Iter: 54000
# D loss: 0.3911
# G_loss: 3.043
# Iter: 55000
# D loss: 0.3597
# G_loss: 3.136
# Iter: 56000
# D loss: 0.3581
# G_loss: 3.21
# Iter: 57000
# D loss: 0.4375
# G_loss: 2.68
# Iter: 58000
# D loss: 0.4765
# G_loss: 3.564
# Iter: 59000
# D loss: 0.4399
# G_loss: 3.263
# Iter: 60000
# D loss: 0.4308
# G_loss: 3.362
# Iter: 61000
# D loss: 0.329
# G_loss: 2.86
# Iter: 62000
# D loss: 0.3616
# G_loss: 3.135
# Iter: 63000
# D loss: 0.5326
# G_loss: 3.382
# Iter: 64000
# D loss: 0.3877
# G_loss: 3.296
# Iter: 65000
# D loss: 0.4279
# G_loss: 3.842
# Iter: 66000
# D loss: 0.3254
# G_loss: 3.044
# Iter: 67000
# D loss: 0.38
# G_loss: 2.961
# Iter: 68000
# D loss: 0.4567
# G_loss: 3.676
# Iter: 69000
# D loss: 0.5231
# G_loss: 3.163
# Iter: 70000
# D loss: 0.4429
# G_loss: 3.783
# Iter: 71000
# D loss: 0.528
# G_loss: 3.544
# Iter: 72000
# D loss: 0.5698
# G_loss: 3.625
# Iter: 73000
# D loss: 0.3803
# G_loss: 3.271
# Iter: 74000
# D loss: 0.3422
# G_loss: 3.839
# Iter: 75000
# D loss: 0.4484
# G_loss: 2.869
# Iter: 76000
# D loss: 0.3734
# G_loss: 3.424
# Iter: 77000
# D loss: 0.404
# G_loss: 3.23
# Iter: 78000
# D loss: 0.6052
# G_loss: 3.63
# Iter: 79000
# D loss: 0.3793
# G_loss: 3.569
# Iter: 80000
# D loss: 0.3527
# G_loss: 3.978
# Iter: 81000
# D loss: 0.4832
# G_loss: 3.361
# Iter: 82000
# D loss: 0.2993
# G_loss: 3.574
# Iter: 83000
# D loss: 0.4334
# G_loss: 3.654
# Iter: 84000
# D loss: 0.4057
# G_loss: 3.411
# Iter: 85000
# D loss: 0.4713
# G_loss: 3.01
# Iter: 86000
# D loss: 0.3315
# G_loss: 3.368
# Iter: 87000
# D loss: 0.4277
# G_loss: 3.249
# Iter: 88000
# D loss: 0.3028
# G_loss: 3.481
# Iter: 89000
# D loss: 0.3627
# G_loss: 3.237
# Iter: 90000
# D loss: 0.4753
# G_loss: 3.812
# Iter: 91000
# D loss: 0.3586
# G_loss: 3.417
# Iter: 92000
# D loss: 0.415
# G_loss: 3.789
# Iter: 93000
# D loss: 0.548
# G_loss: 3.508
# Iter: 94000
# D loss: 0.4254
# G_loss: 3.304
# Iter: 95000
# D loss: 0.2825
# G_loss: 3.847
# Iter: 96000
# D loss: 0.3292
# G_loss: 3.247
# Iter: 97000
# D loss: 0.2073
# G_loss: 3.706
# Iter: 98000
# D loss: 0.3017
# G_loss: 3.788
# Iter: 99000
# D loss: 0.3891
# G_loss: 3.481

# %% [markdown]
# # 使用统计分布的尝试

# %%
def xavier_init(size):
    in_dim = size[0]
    xavier_stddev = 1. / tf.sqrt(in_dim / 2.)
    return tf.random_normal(shape=size, stddev=xavier_stddev)


X = tf.placeholder(tf.float32, shape=[None, 784])

D_W1 = tf.Variable(xavier_init([784, 128]))
D_b1 = tf.Variable(tf.zeros(shape=[128]))

D_W2 = tf.Variable(xavier_init([128, 1]))
D_b2 = tf.Variable(tf.zeros(shape=[1]))

theta_D = [D_W1, D_W2, D_b1, D_b2]

Z = tf.placeholder(tf.float32, shape=[None, 784])

G_W1 = tf.Variable(xavier_init([784, 128]))
G_b1 = tf.Variable(tf.zeros(shape=[128]))

G_W2 = tf.Variable(xavier_init([128, 784]))
G_b2 = tf.Variable(tf.zeros(shape=[784]))

theta_G = [G_W1, G_W2, G_b1, G_b2]


def sample_Z(m, n):
    return np.random.uniform(-1., 1., size=[m, n])


def sample_Z_try(mean, std, m, n):
    result = np.zeros([m, n])
    np.random.seed(0)
    for piexl in range(0, n):
        result[:, piexl] = np.random.normal(mean[piexl], 10*std[piexl], m)

    return result


def generator(z):
    G_h1 = tf.nn.relu(tf.matmul(z, G_W1) + G_b1)
    G_log_prob = tf.matmul(G_h1, G_W2) + G_b2
    G_prob = tf.nn.sigmoid(G_log_prob)

    return G_prob


def discriminator(x):
    D_h1 = tf.nn.relu(tf.matmul(x, D_W1) + D_b1)
    D_logit = tf.matmul(D_h1, D_W2) + D_b2
    D_prob = tf.nn.sigmoid(D_logit)

    return D_prob, D_logit


def plot_sample(samples):
    fig = plt.figure(figsize=(4, 4))
    gs = gridspec.GridSpec(4, 4)
    gs.update(wspace=0.05, hspace=0.05)

    for i, sample in enumerate(samples):
        ax = plt.subplot(gs[i])
        plt.axis('off')
        ax.set_xticklabels([])
        ax.set_yticklabels([])
        ax.set_aspect('equal')
        plt.imshow(sample.reshape(28, 28), cmap='Greys_r')

    return fig


def plot_loss(G_iteration_list, G_loss_list, D_iteration_list, D_loss_list):
    fig = plt.figure()
    plt.plot(G_iteration_list, G_loss_list, 'r')
    plt.plot(D_iteration_list, D_loss_list, 'y')
    plt.xlabel('iteration')
    plt.ylabel('loss')
    plt.legend(['G_loss', 'D_loss'])
    plt.title("G_loss VS D_loss")
    return fig


G_sample = generator(Z)
D_real, D_logit_real = discriminator(X)
D_fake, D_logit_fake = discriminator(G_sample)

# D_loss = -tf.reduce_mean(tf.log(D_real) + tf.log(1. - D_fake))
# G_loss = -tf.reduce_mean(tf.log(D_fake))

# Alternative losses:
# -------------------
D_loss_real = tf.reduce_mean(
    tf.nn.sigmoid_cross_entropy_with_logits(
        logits=D_logit_real, labels=tf.ones_like(D_logit_real)))
D_loss_fake = tf.reduce_mean(
    tf.nn.sigmoid_cross_entropy_with_logits(
        logits=D_logit_fake, labels=tf.zeros_like(D_logit_fake)))
D_loss = D_loss_real + D_loss_fake
G_loss = tf.reduce_mean(
    tf.nn.sigmoid_cross_entropy_with_logits(
        logits=D_logit_fake, labels=tf.ones_like(D_logit_fake)))

D_solver = tf.train.AdamOptimizer().minimize(D_loss, var_list=theta_D)
G_solver = tf.train.AdamOptimizer().minimize(G_loss, var_list=theta_G)

mb_size = 128
Z_dim = 784

mnist = tf.contrib.learn.datasets.mnist.read_data_sets(
    train_dir='mnist/data', one_hot=True)

if not os.path.exists('my_method2_test/'):
    os.makedirs('my_method2_test/')

i = 0
G_iteration_list = []
G_loss_list = []
D_iteration_list = []
D_loss_list = []
with tf.Session(config=config) as sess:
    sess.run(tf.global_variables_initializer())
    for it in range(100000):
        X_mb, _ = mnist.train.next_batch(mb_size)
        cur_mb_mean = np.mean(X_mb, 0)
        cur_mb_std = np.std(X_mb, 0)
        if it % 1000 == 0:
            input_z = sample_Z_try(cur_mb_mean, cur_mb_std, 16, Z_dim)
            fig = plot_sample(input_z)
            plt.show()
            plt.close(fig)
            samples = sess.run(
                G_sample,
                feed_dict={
                    Z: input_z
                })
            fig = plot_sample(samples)
            plt.savefig(
                'my_method2_test/{}.png'.format(str(i).zfill(3)),
                bbox_inches='tight')
            i += 1
            plt.show()
            plt.close(fig)
        _, D_loss_curr = sess.run(
            [D_solver, D_loss],
            feed_dict={
                X: X_mb,
                Z: sample_Z_try(cur_mb_mean, cur_mb_std, mb_size, Z_dim)
            })
        _, G_loss_curr = sess.run(
            [G_solver, G_loss],
            feed_dict={
                Z: sample_Z_try(cur_mb_mean, cur_mb_std, mb_size, Z_dim)
            })
        G_iteration_list.append(it)
        D_iteration_list.append(it)
        G_loss_list.append(G_loss_curr)
        D_loss_list.append(D_loss_curr)

        if it % 1000 == 0:
            fig = plot_loss(G_iteration_list, G_loss_list, D_iteration_list,
                            D_loss_list)
            plt.show()
            plt.close(fig)
            print('Iter: {}'.format(it))
            print('D loss: {:.4}'.format(D_loss_curr))
            print('G_loss: {:.4}'.format(G_loss_curr))
            print()
# Out:
# Extracting mnist/data/train-images-idx3-ubyte.gz
# Extracting mnist/data/train-labels-idx1-ubyte.gz
# Extracting mnist/data/t10k-images-idx3-ubyte.gz
# Extracting mnist/data/t10k-labels-idx1-ubyte.gz
# Iter: 0
# D loss: 1.617
# G_loss: 1.741
# Iter: 1000
# D loss: 0.003741
# G_loss: 9.558
# Iter: 2000
# D loss: 0.0003469
# G_loss: 9.825
# Iter: 3000
# D loss: 0.0002755
# G_loss: 9.277
# Iter: 4000
# D loss: 0.0001861
# G_loss: 12.37
# Iter: 5000
# D loss: 2.142e-05
# G_loss: 11.79
# Iter: 6000
# D loss: 8.123e-06
# G_loss: 13.49
# Iter: 7000
# D loss: 7.459e-06
# G_loss: 18.24
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-4463a067c6dc> in <module>()
#     151             [G_solver, G_loss],
#     152             feed_dict={
# --> 153                 Z: sample_Z_try(cur_mb_mean, cur_mb_std, mb_size, Z_dim)
#     154             })
#     155         G_iteration_list.append(it)
#
# <ipython-input-3-4463a067c6dc> in sample_Z_try(mean, std, m, n)
#      34     np.random.seed(0)
#      35     for piexl in range(0, n):
# ---> 36         result[:, piexl] = np.random.normal(mean[piexl], 10*std[piexl], m)
#      37
#      38     return result
#
# KeyboardInterrupt:
